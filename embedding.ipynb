# %%
import os
from langchain_community.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# 텍스트 분할기 설정
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=0)

# 문서를 저장할 리스트
split_docs = []

# 디렉토리 경로 설정
directory_path = '/workspace/card_db/'

# 디렉토리 내 파일 목록 가져오기
for filename in os.listdir(directory_path):
    if filename.endswith('.txt'):  # .md 파일만 선택
        loader = TextLoader(os.path.join(directory_path, filename))
        split_doc = loader.load_and_split(text_splitter)
        
        # 각 청크에 메타데이터 추가
        for chunk in split_doc:
            chunk.metadata = {'source': filename}  # 문서 이름을 메타데이터로 추가
        
        split_docs.extend(split_doc)  # 리스트에 청크 추가

# 문서 개수 확인
document_counts = [len(doc.page_content) for doc in split_docs]  # page_content의 길이 확인
print(document_counts)

# 문서 개수 출력
total_chunks = len(split_docs)
print(f"총 청크 개수: {total_chunks}")
# Out:
# [440, 443, 487, 452, 247, 473, 227, 478, 424, 108, 207, 424, 108, 196, 424, 108, 250, 424, 108, 229, 424, 108, 256, 424, 108, 205, 435, 219, 435, 297, 426, 469, 360, 147, 416, 239, 299, 473, 373, 462, 457, 461, 250, 405, 285, 426, 141, 324, 439, 112]
# 총 청크 개수: 50

# %%
from langchain_community.embeddings import OllamaEmbeddings
from langchain_chroma import Chroma

# 임베딩 모델 설정
embedding_model = OllamaEmbeddings(model='gemma2')

# DB 생성
db = Chroma.from_documents(
    documents=split_docs,  # 통합된 청크 리스트 사용
    embedding=embedding_model,
    collection_name='card_db'
)

# %%
# 저장할 경로 지정
DB_PATH = '/workspace/card_db/vector'

# 문서를 디스크에 저장
persist_db = Chroma.from_documents(
    documents=split_docs,  # 통합된 청크 리스트 사용
    embedding=embedding_model,
    persist_directory=DB_PATH,
    collection_name='card_db'
)

# %%
# 디스크에서 문서를 로드
persist_db = Chroma(
    persist_directory=DB_PATH,
    embedding_function=embedding_model,
    collection_name='card_db',
)

# %%
# 저장된 데이터 확인
stored_documents = persist_db.get()

# 저장된 문서 내용 출력
print("저장된 문서 내용:")
if isinstance(stored_documents, list):  # 반환된 결과가 리스트인 경우
    for doc in stored_documents:
        # doc이 문자열이면 바로 출력
        if isinstance(doc, str):
            print(doc)
        else:  # doc이 문서 객체인 경우
            print(doc.page_content)  # 문서 객체의 내용 출력
else:
    print(stored_documents)  # 리스트가 아닌 경우, 결과를 그대로 출력
# Out:
# 저장된 문서 내용:
# {'ids': ['0340f866-c7ab-4025-acbb-c52ab8dea839', '6f8d83eb-123b-4371-aa49-75d0b1313315', 'ff2287af-fec7-4285-a91a-6a46e28d887b', 'd85b0b4b-c00e-4eb3-80fe-9528c9e37155', 'bb4f4960-40f0-4b13-8031-77520033169e', '88ce67a3-72a2-4e8c-a8c8-e8f38cf6f7cb', '37f0c0c8-cf11-422b-9f7f-68bb62eb8796', '85b46ad6-c6f1-47bd-9af7-a65da1c617e0', 'f0137492-aeb7-4a31-b434-b08626212351', 'b28b50c8-d179-4b7d-a159-3e13320aeabe', '61993a18-9bf5-4e6c-873a-05eaff4c74ba', '51e89c3e-8bfc-40ad-9538-7a0d60df1c59', '79c04fce-07c5-4e8b-95d9-febd50585815', 'd8a286f3-546c-4f
한카드_Deep_Oil\n\n\n4개의 정유사 (GS칼텍스, SK에너지, S-OIL, 에이치디현대오일뱅크) 중 직접 고른 1개 정유사 주유 이용금액 10% 결제일 할인\n- 정유사 선택은 1곳만 가능하며 연 1회 (1월~12월) 변경 가능합니다.\n- 정유사 미 선택시에는 GS칼텍스가 선택됩니다.\n- 선택한 정유사는 본인/가족회원 동일하게 적용되며, 선택 및 변경은 본인 회원에 한하여 가능합니다.\n- 정유사는 신한카드 홈페이지/앱에서 '내카드관리'. '선택형서비스 조회・변경' 검색 또는 신한카드 고객센터(1544-7000)를 통해 변경하실 수 있습니다. (고객센터는 평일 오전 9시부터 오후 6시까지 운영 시간 내 이용 가능)\n- 정유사 변경 후 다음날 이용거래부터 변경된 정유사에 대해 할인 서비스가 적용됩니다.\n- 휘발유 , 등유, 경유에 대해서만 할인이 제공되며 LPG는 할인 제외됩니다.", '주유서비스 유의 사항\n- 주유서비스는 신한카드 Deep Oil 전월 이용금액 (1일~말일, 일시불+할부, 모든 주유소 주유 및 LPG 이용금액 제외)이 30만원 이상인 경우 제공됩니다.\n- 전월 이용금액에 따른 ‘주유서비스 월 이용금액 한도’내에서 거래 순서에 따라 할인 제공됩니다.\n\n\n[정비소] SpeedMate\n- 스피드메이트 이용금액 10% 결제일 할인\n- 오프라인 현장 일반결제만 가능하며, 온라인 결제 등은 적용 제외됩니다.\n\n[주차장]\n- 전국 모든 주차장 10% 결제일 할인\n- 당사 주차장 업종으로 등록된 가맹점에 한하여 제공됩니다.\n\n차량서비스 유의 사항\n- 차량서비스는 신한카드 Deep Oil 전월 이용금액 (1일~말일, 일시불+할부, 모든 주유소 주유 및 LPG 이용금액 제외)이 30만원 이상인 경우 제공됩니다.\n- 전월 이용금액에 따른 ‘차량서비스 월 이용금액 한도’내 (할인대상 정비소 + 주차장 통합)에서 거래 순서에 따라 할인 제공됩니다.', '[편의점]\n- GS25, CU 5% 결제일 할인\n\n생활서비스 유의 사항\n- 생활서비스는 신한카드 Deep Oil 전월 이용금액 (1일~말일, 일시불+할부, 모든 주유소 주유 및 LPG 이용금액 제외)이 30만원 이상인 경우 제공됩니다.\n- 전월 이용금액에 따른 ‘생활서비스 월 이용금액 한도’내 (할인대상 편의점 + 커피 + 택시 통합)에서 거래 순서에 따라 할인 제공됩니다.\n\n\n[커피]\n- 스타벅스, 이디야 5% 결제일 할인\n- 상품권 구입, 선불카드 충전은 할인 제외됩니다.\n\n생활서비스 유의 사항\n- 생활서비스는 신한카드 Deep Oil 전월 이용금액 (1일~말일, 일시불+할부, 모든 주유소 주유 및 LPG 이용금액 제외)이 30만원 이상인 경우 제공됩니다.\n- 전월 이용금액에 따른 ‘생활서비스 월 이용금액 한도’내 (할인대상 편의점 + 커피 + 택시 통합)에서 거래 순서에 따라 할인 제공됩니다.', '[택시]\n- 택시 5% 결제일 할인\n- 오프라인 현장 일반결제만 가능하며, 온라인/자동결제 등은 적용 제외됩니다.\n\n ...
